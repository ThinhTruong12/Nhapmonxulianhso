# %%
import numpy as np
import imageio.v2 as iio 
import matplotlib.pylab as plt
import scipy.ndimage as nd
data = iio.imread('fruit.jpg')
bmg = data[800:1220, 1550:1880]
print(data.shape)

iio.imsave('apple.jpg',bmg)
plt.imshow(bmg)
plt.show()
# Out:
# (1427, 2100, 3)

# %%
import imageio.v2 as iio
import scipy.ndimage as nd
import matplotlib.pyplot as plt

# Đọc ảnh grayscale
data = iio.imread('fruit.jpg', mode='L')

# Dịch ảnh xuống 50px và sang trái 30px
bdata = nd.shift(data, (50, -30))

# Hiển thị
plt.imshow(bdata, cmap='gray')
plt.axis('off')
plt.show()

# %%
import numpy as np
import scipy.ndimage as nd
import imageio.v2 as iio
import matplotlib.pylab as plt

data = iio.imread('fruit.jpg')
print(data.shape)

# Phóng to gấp 3 lần
data_zoom3 = nd.zoom(data, (3, 3, 1))
print(data_zoom3.shape)
plt.imshow(data_zoom3)
plt.title("Zoom x3")
plt.show()

# Thu nhỏ còn 0.3 lần
data_zoom03 = nd.zoom(data, (0.3, 0.3, 1))
print(data_zoom03.shape)
plt.imshow(data_zoom03)
plt.title("Zoom x0.3")
plt.show()
# Out:
# (1427, 2100, 3)
# (4281, 6300, 3)
# (428, 630, 3)

# %%
import numpy as np
import scipy.ndimage as nd
import imageio.v2 as iio
import matplotlib.pylab as plt

data = iio.imread('fruit.jpg')
print(data.shape)

# Xoay 45 độ với reshape=True (kích thước thay đổi)
rot1 = nd.rotate(data, 45, reshape=True)
print("With reshape=True:", rot1.shape)
plt.imshow(rot1)
plt.title("Rotate 45° (reshape=True)")
plt.show()

# Xoay 45 độ với reshape=False (kích thước giữ nguyên, có thể bị cắt)
rot2 = nd.rotate(data, 45, reshape=False)
print("With reshape=False:", rot2.shape)
plt.imshow(rot2)
plt.title("Rotate 45° (reshape=False)")
plt.show()
# Out:
# (1427, 2100, 3)
# With reshape=True: (2494, 2494, 3)
# With reshape=False: (1427, 2100, 3)

# %%
import numpy as np
import scipy.ndimage as nd
import imageio.v2 as iio
import matplotlib.pylab as plt

data = iio.imread('world_cup.jpg')

# Dilation với size = (5, 5)
dilate = nd.grey_dilation(data, size=(5, 5, 1))
plt.imshow(dilate)
plt.title("Dilation (5x5)")
plt.show()

# Erosion với size = (5, 5)
erode = nd.grey_erosion(data, size=(5, 5, 1))
plt.imshow(erode)
plt.title("Erosion (5x5)")
plt.show()

# %%
import numpy as np
import scipy.ndimage as nd
import imageio.v2 as iio
import matplotlib.pyplot as plt

def GeoFun(outcoord):
    a = 5 * np.sin(outcoord[0]/5.0) + outcoord[0]
    b = 5 * np.sin(outcoord[1]/5.0) + outcoord[1]
    return a, b

# Đọc ảnh
data = iio.imread('world_cup.jpg', mode='L')

# Áp dụng biến đổi hình học
d1 = nd.geometric_transform(data, GeoFun)
plt.imshow(d1, cmap='gray')
plt.title("Geometric Transform with sin")
plt.show()
